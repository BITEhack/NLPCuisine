# %% [markdown]
# # **Import**

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import re

import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

from sklearn.preprocessing import LabelEncoder

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # **Data preview**

# %%
trainframe = pd.read_json("train.json")
testframe = pd.read_json("test.json")

# %%
trainframe.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
trainframe.tail()
# Out:
#           id  cuisine                                        ingredients
# 39769  29109    irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462  italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238    irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882  chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362  mexican  [green chile, jalapeno chilies, onions, ground...

# %%
trainframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39774 entries, 0 to 39773
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           39774 non-null  int64
#  1   cuisine      39774 non-null  object
#  2   ingredients  39774 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 932.3+ KB

# %%
trainframe['cuisine'].value_counts()
# Out:
# italian         7838
# mexican         6438
# southern_us     4320
# indian          3003
# chinese         2673
# french          2646
# cajun_creole    1546
# thai            1539
# japanese        1423
# greek           1175
# spanish          989
# korean           830
# vietnamese       825
# moroccan         821
# british          804
# filipino         755
# irish            667
# jamaican         526
# russian          489
# brazilian        467
# Name: cuisine, dtype: int64

# %%
trainframe['ingredients'].values
# Out:
# array([list(['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles']),
#        list(['plain flour', 'ground pepper', 'salt', 'tomatoes', 'ground black pepper', 'thyme', 'eggs', 'green tomatoes', 'yellow corn meal', 'milk', 'vegetable oil']),
#        list(['eggs', 'pepper', 'salt', 'mayonaise', 'cooking oil', 'green chilies', 'grilled chicken breasts', 'garlic powder', 'yellow onion', 'soy sauce', 'butter', 'chicken livers']),
#        ...,
#        list(['eggs', 'citrus fruit', 'raisins', 'sourdough starter', 'flour', 'hot tea', 'sugar', 'ground nutmeg', 'salt', 'ground cinnamon', 'milk', 'butter']),
#        list(['boneless chicken skinless thigh', 'minced garlic', 'steamed white rice', 'baking powder', 'corn starch', 'dark soy sauce', 'kosher salt', 'peanuts', 'flour', 'scallions', 'Chinese rice vinegar', 'vodka', 'fresh ginger', 'egg whites', 'broccoli', 'toasted sesame seeds', 'sugar', 'store bought low sodium chicken stock', 'baking soda', 'Shaoxing wine', 'oil']),
#        list(['green chile', 'jalapeno chilies', 'onions', 'ground black pepper', 'salt', 'chopped cilantro fresh', 'green bell pepper', 'garlic', 'white sugar', 'roma tomatoes', 'celery', 'dried oregano'])],
#       dtype=object)

# %% [markdown]
# # **Ingredients analysis**

# %%
pattern = re.compile("^[a-zA-Z ]*$")

# %%
# that code is dumb - don't look at it

# check if all words are "reasonable" - just testing
uwu = [ingredient if pattern.match(ingredient) is None else None for ingredients_list in trainframe['ingredients'] for ingredient in ingredients_list]

# for x in uwu:
#     if x is not None:
#         print(x)

# of course they are not

owo = []
# uwu = [pattern.sub(" ", str(ingredient))  if ingredient is not None for ingredient in uwu]

for x in uwu:
    if x is not None:
        owo.append(re.sub("[^a-zA-Z $]", " ", str(x)))

print(sorted(owo))
owo
# Out:
# ['      oz   diced tomatoes', '      oz   diced tomatoes', '      oz   diced tomatoes', '      to   lb  chicken  cut into serving pieces', '      to   lb  chicken  cut into serving pieces', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '     oz   tomato sauce', '    lean ground beef', '    lean ground beef', '    lean ground beef', '    lean ground beef', '    less sodium chicken broth', '    less sodium chicken broth', '    less sodium chicken broth', '    less sodium cooked deli ham', '    less sodium cooked ham', '    less sodium ham', '    less sodium ham', '    less sodium ham', '    less sodium smoked fully cooked ham', '    less sodium taco seasoning', '    less sodium taco seasoning', '    less sodium taco seasoning', '    less sodium taco seasoning', '    less sodium taco seasoning', '    less sodium taco seasoning', '    less sodium taco seasoning', '    less sodium taco seasoning mix', '    less sodium taco seasoning mix', '    less sodium taco seasoning mix', '    less sodium taco seasoning mix', '    less sodium taco seasoning mix', '    oz   frozen chopped spinach', '    oz   frozen chopped spinach', '    oz   frozen chopped spinach', '    oz   frozen chopped spinach  thawed and squeezed dry', '    oz   frozen chopped spinach  thawed and squeezed dry', '    oz   refried beans', '    oz   refried beans', '    oz   refried beans', '    oz   sweetened condensed milk', '    oz   sweetened condensed milk', '    oz   tomato paste', '    oz   tomato paste', '    oz   tomato paste', '    oz   tomato paste', '    oz   tomato paste', '    oz   tomato paste', '    oz   tomato paste', '    oz   tomato paste', '    oz   tomato paste', '   low fat buttermilk', '   low fat buttermilk', '   low fat buttermilk', '   low fat buttermilk', '   low fat cheddar chees', '   low fat chocolate milk', '   low fat chocolate milk', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat cottage cheese', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low fat milk', '   low  ...
# ['extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'broiler fryer chicken',
#  'low fat mayonnaise',
#  'all purpose flour',
#  'all purpose flour',
#  'chinese five spice powder',
#  'black eyed peas',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'part skim mozzarella cheese',
#  'low fat sour cream',
#  '   low fat milk',
#  'pumpkin pur e',
#  'demi glace',
#  'all purpose flour',
#  'all purpose flour',
#  'kahl a',
#  'all purpose flour',
#  'part skim mozzarella cheese',
#  'english muffins  split and toasted',
#  'all purpose flour',
#  'all purpose flour',
#  'chinese five spice powder',
#  'all purpose flour',
#  'all purpose flour',
#  '   reduced fat milk',
#  'long grain rice',
#  'kahl a',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'low fat natural yogurt',
#  'bone in chicken breasts',
#  'long grain rice',
#  'short grain rice',
#  'extra virgin olive oil',
#  'kahl a',
#  'plain whole milk yogurt',
#  'all purpose flour',
#  'extra lean ground beef',
#  'green bell pepper  slice',
#  'all purpose flour',
#  'hard boiled egg',
#  'grated Gruy re cheese',
#  'all purpose flour',
#  'part skim ricotta cheese',
#  'part skim mozzarella cheese',
#  'extra virgin olive oil',
#  'black eyed peas',
#  'all purpose flour',
#  'semi sweet chocolate morsels',
#  'steel cut oats',
#  'red kidnei beans  rins and drain',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'whole kernel corn  drain',
#  'water chestnuts  drained and chopped',
#  'all purpose flour',
#  '   reduced fat milk',
#  'whole kernel corn  drain',
#  'all purpose flour',
#  'all purpose flour',
#  'tomato pur e',
#  'low fat sour cream',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'fat free refried beans',
#  'low fat milk',
#  'chinese five spice powder',
#  'Bertolli  Classico Olive Oil',
#  'bacon  crisp cooked and crumbled',
#  '     oz   tomato sauce',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'half   half',
#  'shell on shrimp',
#  'half   half',
#  'all purpose flour',
#  'Old El Paso  mild red enchilada sauce',
#  'Pillsbury  Refrigerated Crescent Dinner Rolls',
#  'sun dried tomatoes in oil',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'cr me fra che',
#  'double acting baking powder',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'cream cheese  soften',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'cream cheese  soften',
#  'fat free cottage cheese',
#  'part skim mozzarella cheese',
#  'oven ready lasagna noodles',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'Sargento  Traditional Cut Shredded Mozzarella Cheese',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'short grain rice',
#  'shell on shrimp',
#  'all purpose flour',
#  'long grain rice',
#  'gluten free tamari',
#  'uncook medium shrimp  peel and devein',
#  'sun dried tomatoes',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'non fat sour cream',
#  'fat free mayonnaise',
#  'extra virgin olive oil',
#  'sheep s milk cheese',
#  'extra virgin olive oil',
#  'long grain rice',
#  'sun dried tomatoes',
#  'all purpose flour',
#  'low fat buttermilk',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'brine cured black olives',
#  'all purpose flour',
#  'green bell pepper  slice',
#  'all purpose flour',
#  'cr me fra che',
#  'chinese five spice powder',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'gluten free hoisin sauce',
#  'chinese five spice powder',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'Campbell s Condensed Tomato Soup',
#  'chinese five spice powder',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'Hellmann  s Light Mayonnaise',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'cr me fra che',
#  'whole kernel corn  drain',
#  'cr me fra che',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'bone in chicken breast halves',
#  'non fat sour cream',
#  'extra virgin olive oil',
#  'Ni oise olives',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'low fat coconut milk',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'part skim mozzarella cheese',
#  'extra virgin olive oil',
#  'bow tie pasta',
#  'half   half',
#  'extra virgin olive oil',
#  'cream cheese  soften',
#  'long grain rice',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'roast red peppers  drain',
#  'chinese five spice powder',
#  'part skim mozzarella cheese',
#  'part skim ricotta cheese',
#  'low fat cottage cheese',
#  'soft goat s cheese',
#  'tomato pur e',
#  'all purpose flour',
#  'quick cooking barley',
#  'low fat soy milk',
#  'all purpose flour',
#  'all purpose flour',
#  'bow tie pasta',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'green bell pepper  slice',
#  'red bell pepper  sliced',
#  '   low fat cottage cheese',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'tomato pur e',
#  'hard boiled egg',
#  'extra virgin olive oil',
#  'quatre  pices',
#  'old fashioned oats',
#  'all purpose flour',
#  'parmigiano reggiano cheese',
#  'extra virgin olive oil',
#  'low fat buttermilk',
#  'all purpose flour',
#  'black eyed peas',
#  'Jell O Gelatin Dessert',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'tomato pur e',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'grated Gruy re cheese',
#  'bow tie pasta',
#  'all purpose flour',
#  'kahl a',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'black eyed peas',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'stone ground cornmeal',
#  'half   half',
#  'reduced fat cheese',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'fat trimmed beef flank steak',
#  'low fat coconut milk',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'part skim mozzarella cheese',
#  'self rising cake flour',
#  'long grain rice',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'part skim mozzarella cheese',
#  'soft boiled egg',
#  'soft goat s cheese',
#  'all purpose flour',
#  'old fashioned oats',
#  'chinese five spice powder',
#  'extra virgin olive oil',
#  'parmigiano reggiano cheese',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'soft goat s cheese',
#  'all purpose flour',
#  'Campbell s Condensed Cream of Chicken Soup',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'cr me fra che',
#  'extra virgin olive oil',
#  'part skim mozzarella cheese',
#  '   low fat milk',
#  'all purpose flour',
#  'half   half',
#  'plain low fat yogurt',
#  'all purpose flour',
#  'long grain rice',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'low fat sour cream',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'cream cheese  soften',
#  'long grain rice',
#  'pumpkin pur e',
#  'all purpose flour',
#  'tomato pur e',
#  'oven ready lasagna noodles',
#  'part skim ricotta cheese',
#  'all purpose flour',
#  'frozen mixed thawed vegetables ',
#  'all purpose flour',
#  '   low fat milk',
#  'half   half',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'extra virgin olive oil',
#  'medium grain rice',
#  'long grain rice',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'tomato pur e',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'chinese five spice powder',
#  'chinese five spice powder',
#  'reduced fat sour cream',
#  'all purpose flour',
#  'plain low fat yogurt',
#  '   low fat milk',
#  'all purpose flour',
#  '   low fat milk',
#  'all purpose flour',
#  'all purpose flour',
#  'semi sweet chocolate morsels',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'self rising cornmeal',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'black eyed peas',
#  'all purpose flour',
#  'parmigiano reggiano cheese',
#  'extra virgin olive oil',
#  'plain whole milk yogurt',
#  'part skim mozzarella cheese',
#  'all purpose flour',
#  'thick cut bacon',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'half   half',
#  'chinese five spice powder',
#  'all purpose flour',
#  'besan  flour ',
#  'chinese five spice powder',
#  'long grain rice',
#  'long grain rice',
#  'all purpose flour',
#  'half   half',
#  'all purpose flour',
#  'all purpose flour',
#  'Country Crock  Spread',
#  'all purpose flour',
#  'long grain rice',
#  '   low fat milk',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'boneless  skinless chicken breast',
#  'sun dried tomatoes',
#  'extra virgin olive oil',
#  'reduced fat sour cream',
#  'green bell pepper  slice',
#  'all purpose flour',
#  'fat free chicken broth',
#  'all purpose flour',
#  'all purpose flour',
#  'cream cheese  soften',
#  'all purpose flour',
#  'all purpose flour',
#  'long grain rice',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'brine cured black olives',
#  '    oz   frozen chopped spinach  thawed and squeezed dry',
#  'bow tie pasta',
#  'half   half',
#  'short grain rice',
#  'part skim mozzarella cheese',
#  'whole kernel corn  drain',
#  'extra virgin olive oil',
#  'non fat sour cream',
#  'all purpose flour',
#  'low fat buttermilk',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'cream cheese  soften',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'half   half',
#  'black eyed peas',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'black eyed peas',
#  'long grain rice',
#  'all purpose flour',
#  'all purpose flour',
#  'fettuccine  cook and drain',
#  'tomato pur e',
#  'low fat buttermilk',
#  'all purpose flour',
#  'lemon lime soda',
#  'extra virgin olive oil',
#  '   reduced fat milk',
#  'half   half',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'cr me fra che',
#  'mexican style   cheese blend',
#  'half   half',
#  'all purpose flour',
#  'pumpkin pur e',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  '   low fat milk',
#  'all purpose flour',
#  '   low fat buttermilk',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'long grain rice',
#  'all purpose flour',
#  'half   half',
#  '   reduced fat milk',
#  'reduced fat sour cream',
#  'all purpose flour',
#  'part skim mozzarella cheese',
#  'all purpose flour',
#  'hard boiled egg',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'long grain rice',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'clams  well scrub',
#  'extra virgin olive oil',
#  'oven ready lasagna noodles',
#  'part skim mozzarella cheese',
#  'part skim ricotta cheese',
#  'all purpose flour',
#  'half   half',
#  'grated Gruy re cheese',
#  'all purpose flour',
#  'coarse grain salt',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'whole kernel corn  drain',
#  'Old El Paso  chopped green chiles',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'Country Crock  Spread',
#  'hellmann  or best food real mayonnais',
#  '   low fat milk',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'Wish Bone Italian Dressing',
#  'red bell pepper  sliced',
#  'green bell pepper  slice',
#  'all purpose flour',
#  'all purpose flour',
#  'hellmann  or best food real mayonnais',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'Knorr  Beef Bouillon',
#  'extra virgin olive oil',
#  'OREO  Cookies',
#  'long grain rice',
#  'red kidnei beans  rins and drain',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'sun dried tomatoes',
#  'all purpose flour',
#  'cream cheese  soften',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'long grain rice',
#  'black eyed peas',
#  'black eyed peas',
#  'extra virgin olive oil',
#  'non fat sour cream',
#  'half   half',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'non fat sour cream',
#  'all purpose flour',
#  'I Can t Believe It s Not Butter   Spread',
#  'all purpose flour',
#  'plain whole milk yogurt',
#  'extra virgin olive oil',
#  'Ni oise olives',
#  'low fat milk',
#  'all purpose flour',
#  'hellmann  or best food real mayonnais',
#  'self rising cornmeal',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'chinese five spice powder',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'e fu noodl',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'parmigiano reggiano cheese',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'chinese five spice powder',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'pumpkin pur e',
#  'all purpose flour',
#  'all purpose flour',
#  'no salt added black beans',
#  'part skim ricotta cheese',
#  'extra virgin olive oil',
#  'whole kernel corn  drain',
#  'all purpose flour',
#  '   reduced fat milk',
#  'all purpose flour',
#  'tomato pur e',
#  'half   half',
#  'all purpose flour',
#  'long grain rice',
#  'greek style vinaigrette',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'long grain rice',
#  'sun dried tomatoes',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'low fat sour cream',
#  'black eyed peas',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'half   half',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'sun dried tomatoes',
#  'all purpose flour',
#  'half   half',
#  'half   half',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'half   half',
#  'extra virgin olive oil',
#  'long grain rice',
#  'ros  wine',
#  'half   half',
#  'all purpose flour',
#  'cr me fra che',
#  'extra virgin olive oil',
#  'half   half',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'half   half',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'bow tie pasta',
#  'all purpose flour',
#  'sweet potatoes   yams',
#  'self rising cornmeal',
#  'half   half',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'grated Gruy re cheese',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'low fat sour cream',
#  'cream cheese  soften',
#  'extra virgin olive oil',
#  'sun dried tomatoes in oil',
#  'half   half',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'bow tie pasta',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'reduced fat sour cream',
#  'cr me fra che',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'whole kernel corn  drain',
#  'all purpose flour',
#  'part skim ricotta cheese',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'soft wheat flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'plain low fat yogurt',
#  'cream cheese  soften',
#  'black eyed peas',
#  'all purpose flour',
#  'Zatarain s Jambalaya Mix',
#  'sweet italian sausag links  cut into',
#  'extra virgin olive oil',
#  'cr me fra che',
#  'sweet potatoes   yams',
#  'all purpose flour',
#  'long grain rice',
#  'all purpose flour',
#  'Ni oise olives',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'Old El Paso  chopped green chiles',
#  'all purpose flour',
#  'gluten free chicken stock',
#  'all purpose flour',
#  'cream cheese  soften',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'half   half',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'hellmann  or best food real mayonnais',
#  'whole kernel corn  drain',
#  'extra virgin olive oil',
#  'whole kernel corn  drain',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'half   half',
#  'all purpose flour',
#  'long grain rice',
#  'black eyed peas',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'part skim ricotta cheese',
#  'long grain rice',
#  'five spice powder',
#  'Ni oise olives',
#  'extra virgin olive oil',
#  'double acting baking powder',
#  'all purpose flour',
#  'no salt added diced tomatoes',
#  'no salt added black beans',
#  'all purpose flour',
#  'all purpose flour',
#  'fat free chicken broth',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'reduced fat sour cream',
#  '   low fat milk',
#  'all purpose flour',
#  'all purpose flour',
#  'chinese five spice powder',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'green bell pepper  slice',
#  'red bell pepper  sliced',
#  'extra virgin olive oil',
#  'chinese five spice powder',
#  'whole kernel corn  drain',
#  'all purpose flour',
#  'low fat yogurt',
#  'long grain rice',
#  'all purpose flour',
#  'non dairy margarine',
#  'roast red peppers  drain',
#  'long grain rice',
#  'cream cheese  soften',
#  'long grain rice',
#  'extra virgin olive oil',
#  'black eyed peas',
#  'long grain rice',
#  'long grain rice',
#  'plain low fat yogurt',
#  'hellmann  or best food real mayonnais',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'low fat plain yogurt',
#  'all purpose flour',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'beef demi glace',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  '   low fat milk',
#  'all purpose flour',
#  'parmigiano reggiano cheese',
#  'extra virgin olive oil',
#  'green bell pepper  slice',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'long grain rice',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'egg noodles  cooked and drained',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'non fat sour cream',
#  'low fat sour cream',
#  'sun dried tomatoes in oil',
#  'lasagna noodles  cooked and drained',
#  'part skim mozzarella cheese',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'reduced fat sour cream',
#  'part skim mozzarella cheese',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'fat free refried beans',
#  'low fat sour cream',
#  'all purpose flour',
#  'cream cheese  soften',
#  'cr me fra che',
#  'plain low fat yogurt',
#  'reduced fat sour cream',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'half   half',
#  'all purpose flour',
#  'all purpose flour',
#  'green bell pepper  slice',
#  'extra virgin olive oil',
#  'small capers  rins and drain',
#  'all purpose flour',
#  'all purpose flour',
#  'whole kernel corn  drain',
#  'all purpose flour',
#  'part skim mozzarella cheese',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'Ni oise olives',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'black eyed peas',
#  'chinese five spice powder',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'lasagna noodles  cooked and drained',
#  'half   half',
#  'all purpose flour',
#  'low fat vanilla ice cream',
#  'curly leaf parsley',
#  'Old El Paso  taco seasoning mix',
#  'black eyed peas',
#  'extra virgin olive oil',
#  'Campbell s Condensed Cheddar Cheese Soup',
#  'all purpose flour',
#  'whole kernel corn  drain',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'chinese five spice powder',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'low fat cottage cheese',
#  'all purpose flour',
#  'sun dried tomatoes',
#  'extra virgin olive oil',
#  'non fat sour cream',
#  '   low fat milk',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'hard boiled egg',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'part skim mozzarella cheese',
#  'extra virgin olive oil',
#  'tomato pur e',
#  'cr me fra che',
#  'all purpose flour',
#  'bone in chicken breast halves',
#  'extra virgin olive oil',
#  'ros  wine',
#  'half   half',
#  'extra virgin olive oil',
#  'non fat sour cream',
#  'low fat shredded cheddar cheese',
#  'all purpose flour',
#  'parmigiano reggiano cheese',
#  'Hellmann s  Real Mayonnaise',
#  'all purpose flour',
#  'all purpose flour',
#  'black eyed peas',
#  'half   half',
#  'all purpose flour',
#  'long grain rice',
#  'half   half',
#  'all purpose flour',
#  'black eyed peas',
#  'all purpose flour',
#  'thick cut bacon',
#  'all purpose flour',
#  'low fat refried beans',
#  'low fat buttermilk',
#  'bone in pork chops',
#  'Old El Paso  chopped green chiles',
#  'Old El Paso  taco seasoning mix',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'sun dried tomatoes',
#  'extra virgin olive oil',
#  'Wish Bone Italian Dressing',
#  'red bell pepper  sliced',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'cr me fra che',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'grated Gruy re cheese',
#  'a ai',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'sun dried tomatoes in oil',
#  'all purpose flour',
#  'low fat sour cream',
#  '   low fat milk',
#  'all purpose flour',
#  'english muffins  split and toasted',
#  'fat free mayonnaise',
#  'all purpose flour',
#  'cr me fra che',
#  'all purpose flour',
#  'all purpose flour',
#  'hellmann  or best food real mayonnais',
#  'corn on the cob',
#  'extra virgin olive oil',
#  'plain whole milk yogurt',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'long grain rice',
#  'low fat buttermilk',
#  'BACARDI  Mixers Margarita Mix',
#  'BACARDI  Superior',
#  'self rising cornmeal',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'english muffins  split and toasted',
#  'extra virgin olive oil',
#  'half   half',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'Jell O Gelatin Dessert',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'long grain rice',
#  'thick cut bacon',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'pumpkin pur e',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'soft shell clams',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'all purpose flour',
#  'cream cheese  soften',
#  'pumpkin pur e',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'Uncle Ben s Original Converted Brand rice',
#  'low fat milk',
#  'part skim mozzarella cheese',
#  'all purpose flour',
#  'low fat plain yogurt',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'bone in chicken breast halves',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'shredded low fat sharp cheddar',
#  'all purpose flour',
#  'all purpose flour',
#  'all purpose flour',
#  'long grain rice',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'mexican style   cheese blend',
#  'non fat sour cream',
#  'all purpose flour',
#  'extra virgin olive oil',
#  'extra virgin olive oil',
#  'cr me fra che',
#  'all purpose flour',
#  ...]

# %% [markdown]
# # **Data preparation**

# %%
lemmatizer = WordNetLemmatizer()

# just to compare with TfidfVectorize - we got 3 times less results using library for NLP
ingredients = list(set(lemmatizer.lemmatize(re.sub("[^a-zA-Z $]", " ", str(ingredient))) for ingredients_list in trainframe['ingredients'] for ingredient in ingredients_list))

# %%
ingredients
# Out:
# ['turkey salami',
#  'gluten free breadcrumbs',
#  'vegetable demi glace',
#  'caponata',
#  'palm oil',
#  'parmigiano reggiano cheese',
#  'brownie layer',
#  'sodium reduced beef broth',
#  'Diamond Crystal  Kosher Salt',
#  'baton',
#  'cracker crumbs',
#  'methi',
#  'farofa',
#  'nut oil',
#  'Gourmet Garden Parsley',
#  'low fat ricotta',
#  'wheat bread',
#  'chinese mustard',
#  'spicy mayonnaise',
#  'pineapple chunks in natural juice',
#  'Cinnamon Toast Crunch Cereal',
#  'sugar cane juice',
#  'fresh orange juice',
#  'boneless duck breast halves',
#  'whipped cream',
#  'pastina',
#  'genmai miso',
#  'kampyo',
#  'dumpling skins',
#  'komatsuna',
#  'chocolate leaves',
#  'salted dry roasted peanuts',
#  'guinea hens',
#  'fresh curry',
#  'buttermilk biscuits',
#  'chocolate spread',
#  'red beans',
#  'vegetable fats',
#  'oyster liquor',
#  'light pancake syrup',
#  'ginkgo nut',
#  'dried oregano',
#  'anchovy filets',
#  'paratha',
#  'soy glaze',
#  'laurel leaves',
#  'pepper jack',
#  'clementine juice',
#  'moose',
#  'rustic bread',
#  'dried black mushrooms',
#  'canning salt',
#  'lime zest',
#  'pumpkin seeds',
#  'spring rolls',
#  'long green',
#  'small white beans',
#  'oil cured black olives',
#  'pesto sauce',
#  'italian chicken sausage',
#  'reduced sodium refried beans',
#  'reduced fat cream of mushroom soup',
#  'powdered egg whites',
#  'egg noodles  cooked and drained',
#  'unsalted pumpkinseed kernels',
#  'chinese winter melon',
#  'jack cheese',
#  'chicken drumsticks',
#  'low fat chunky mushroom pasta sauce',
#  'coleslaw',
#  'Swanson Vegetable Broth',
#  'shoulder steak',
#  'calamari',
#  'boneless skinless chicken breasts',
#  'granny smith apples',
#  'potato chips',
#  'rump steak',
#  'chopped parsley',
#  'chicken breast fillets',
#  'barley flour',
#  'ragu cheesi classic alfredo sauc',
#  'fish balls',
#  'Knorr Onion Minicubes',
#  'brown mushroom',
#  'Bertolli Garlic Alfredo Sauce',
#  'chicken livers',
#  'swiss',
#  'alphabet pasta',
#  'loin pork chops',
#  'honeydew melon',
#  'cumin seed',
#  'pickling salt',
#  'organic vegetable broth',
#  'pork baby back ribs',
#  'red wine vinaigrette',
#  'pork belly',
#  'hubbard squash',
#  'croissant',
#  'pandanus leaf',
#  'white onion',
#  'ginger root',
#  'kidney',
#  'pork bouillon cube',
#  'pappardelle pasta',
#  'free range chicken breasts',
#  'catfish fillets',
#  'grape tomatoes',
#  'pork',
#  'dark corn syrup',
#  'jalape',
#  'candied peel',
#  'red',
#  'onion soup',
#  'pattypan squash',
#  'canton noodles',
#  'lemonade concentrate',
#  'pita wedges',
#  'Maggi',
#  'saffron threads',
#  'chili habanero pepper',
#  'pitted prunes',
#  'wing sauce',
#  'dark ale',
#  'cassava',
#  'boneless chicken thighs',
#  'dried mango',
#  'sushi nori',
#  'pippin apples',
#  'pappardelle',
#  'gluten free oyster sauce',
#  'whole nutmegs',
#  'ground turkey breast',
#  'diced chicken',
#  'extra virgin coconut oil',
#  'TACO BELL  HOME ORIGINALS  Taco Seasoning Mix',
#  'hungarian paprika',
#  'Good Seasons Italian Dressing Mix',
#  'Belgian endive',
#  'orange flavored brandy',
#  'chili seasoning',
#  'manioc flour',
#  'Jasmine brown rice',
#  'DeLallo Extra Virgin Olive Oil',
#  'spice cake mix',
#  'reposado',
#  'medium salsa',
#  'fines herbes',
#  'low fat bottled italian dressing',
#  'blanco tequila',
#  'decorating sugars',
#  'bottled clam juice',
#  'thickener',
#  'boneless chop pork',
#  'goose fat',
#  'roux',
#  'dried mint flakes',
#  'old bay seasoning',
#  'goya sazon',
#  'italian sauce',
#  'Mazola Canola Oil',
#  'round loaf',
#  'fat free ground turkey breast',
#  'chocolate flavored liqueur',
#  'toasted shredded coconut',
#  'dried tarragon leaves',
#  'pork country style ribs',
#  'cucuzza',
#  'unsalted beef stock',
#  'gooseberry',
#  'wax beans',
#  'pita bread',
#  'curly leaf spinach',
#  'whipped cream cheese',
#  'Knorr  Beef Bouillon',
#  'hillshire farms low fat sausage',
#  'brine cured black olives',
#  'banana extract',
#  'wheat bran',
#  'tawny port',
#  'peanut sauce',
#  'steamed brown rice',
#  'chicken gravy mix',
#  'red bliss potato',
#  'crystallized ginger',
#  'grass fed butter',
#  'durum wheat flour',
#  'non dairy milk',
#  'smoked ham hocks',
#  'unsweetened baking chocolate',
#  'proscuitto di parma',
#  'nonfat dry milk',
#  'chocolate fudge ice cream',
#  '   low fat milk',
#  'paella rice',
#  'allspice',
#  'lettuce',
#  'lamb shoulder',
#  'morsel',
#  'frozen mini ravioli',
#  'chopped onion',
#  'roasted chestnuts',
#  'green tomatoes',
#  'schnapps',
#  'poppy seed filling',
#  'dried chestnuts',
#  'apricot preserves',
#  'swede',
#  'whole grain thin spaghetti',
#  'sage leaves',
#  'pizza crust',
#  'ravioli',
#  'bow tie pasta',
#  'stewing steak',
#  'lo bok',
#  'powdered gelatin',
#  'dark molasses',
#  'fiddlehead ferns',
#  'chocolate shavings',
#  'brioche',
#  'shrimp powder',
#  'purple grapes',
#  'low fat vanilla yogurt',
#  'cortland apples',
#  'compote',
#  'pressed tofu',
#  'creole seasoning mix',
#  'rib eye roast',
#  'raspberry liqueur',
#  'campanelle',
#  'fried garlic',
#  'brie cheese',
#  'hellmann    or best food canola cholesterol free mayonnais',
#  'chia seeds',
#  'swordfish',
#  'carnation',
#  'sandwich',
#  'boneless beef rib eye steaks',
#  'unbleached flour',
#  'lamb leg steaks',
#  'smoked cheddar cheese',
#  'anise liqueur',
#  'India Pale Ale',
#  'cayenne pepper',
#  'large eggs',
#  'andouille chicken sausage',
#  'Lipton  Recipe Secrets  Onion Soup Mix',
#  'jerk seasoning mix',
#  'mustard seeds',
#  'glaze',
#  'extra fine granulated sugar',
#  'green pumpkin seeds',
#  'canned beans',
#  'oyster mushrooms',
#  'fresh rosemary',
#  'salsa verde',
#  'mussels  well scrubbed',
#  'frozen cherries',
#  'pie pastry',
#  'yucca root',
#  'tostada',
#  'boneless beef chuck roast',
#  'ground chipotle chile pepper',
#  'Kraft Big Slice Pepper Jack Cheese Slices',
#  'treviso',
#  'poblano peppers',
#  'collard leaves',
#  'bread rolls',
#  'blue cheese',
#  'goma',
#  'tentacle',
#  'italian sausage',
#  'stevia',
#  'sugar cubes',
#  'boneless moulard duck breast halves',
#  'conchiglie',
#  'acai juice',
#  'halibut',
#  'mushroom caps',
#  'redfish fillet',
#  'chile paste with garlic',
#  'vegan butter',
#  'white vermouth',
#  'mutton',
#  'gingersnap',
#  'cucumber',
#  'field peas',
#  'dark chocolate chip',
#  'cr me de menthe',
#  'fast rising yeast',
#  'abalone',
#  'fruit puree',
#  'beef stew meat',
#  'white sandwich bread',
#  'tahini paste',
#  'farro',
#  'chicory',
#  'sirloin tip roast',
#  'ciabatta buns',
#  'Uncle Ben s Original Converted Brand rice',
#  'white corn',
#  'culantro',
#  'quail eggs',
#  'mild curry paste',
#  'double crust',
#  'dried scallops',
#  'alaskan king salmon',
#  'beef stock',
#  'pane di casa',
#  'burrito seasoning mix',
#  'chocolate glaze',
#  'mesquite flavored seasoning mix',
#  'cake flour',
#  'dried coconut flakes',
#  'muffin mix',
#  'lavender honey',
#  'whole peeled tomatoes',
#  'pea',
#  'coconut',
#  'whole wheat angel hair pasta',
#  'raw milk',
#  'hot chili paste',
#  'balsamic vinegar',
#  'unsulphured molasses',
#  'pomegranate juice',
#  'Lipton Sparkling Diet Green Tea with Strawberry Kiwi',
#  'fresh brussels sprouts',
#  'yellow hominy',
#  'red raspberries',
#  'almond meal',
#  'lemon vodka',
#  'grated cotija',
#  'ponzu',
#  'shredded parmesan cheese',
#  'quick cooking hominy grits',
#  'pig',
#  'hot pepper sauce',
#  'sliced salami',
#  'bisquick',
#  'plain low fat greek yogurt',
#  'tartlet shells',
#  'meal',
#  'creamy peanut butter',
#  'cinnamon graham crackers',
#  'lemon pepper',
#  'reduced fat provolone cheese',
#  'fat free lemon curd',
#  'ramen noodles',
#  'Pam Cooking Spray',
#  'plum',
#  'sodium free chicken broth',
#  'Manzanilla olives',
#  'low sodium vegetable juice',
#  'golden beets',
#  'rainbow trout',
#  'simple syrup',
#  'Angostura bitters',
#  'rye',
#  'longaniza',
#  'anchovy paste',
#  'chinese cabbage',
#  'fresno chiles',
#  'refrigerated pizza dough',
#  'chinese rock sugar',
#  'flaked coconut',
#  'baking spray',
#  'sea bream',
#  'mentsuyu',
#  'refried beans',
#  'banh hoi',
#  'marrow',
#  'bihon',
#  'cilantro pesto',
#  'Success White Rice',
#  'ground Italian sausage',
#  'roquefort',
#  'candied cherries',
#  'back bacon rashers',
#  'ginger ale',
#  'pimenton de la vera',
#  'wheatberries',
#  'lettuce leaves',
#  'regular cucumber',
#  'liverwurst',
#  'ground blanched almonds',
#  'italian tomatoes',
#  'center cut pork chops',
#  'tapenade',
#  'riblets',
#  'benne seed',
#  'tomato sauce',
#  'sugar cane',
#  'nonfat sweetened condensed milk',
#  'chocolate frosting',
#  'roasted pepitas',
#  'Accent Seasoning',
#  'deveined shrimp',
#  'chili garlic paste',
#  'white poppy seeds',
#  'steel cut oats',
#  'pickled onion',
#  'smoked pork',
#  'ziti',
#  'spicy salami',
#  'cress',
#  'calvados',
#  'dried fig',
#  'penne',
#  'monkfish fillets',
#  'pita bread rounds',
#  'Earth Balance Natural Buttery Spread',
#  'dried cloud ears',
#  'fat free reduced sodium chicken broth',
#  'Jell O Gelatin Dessert',
#  'pork sirloin',
#  'mo hanh',
#  'triscuits',
#  'salmon steaks',
#  'Spike Seasoning',
#  'chinese radish',
#  'white cabbage',
#  'hot italian pork sausage',
#  'jerk marinade',
#  'adzuki beans',
#  'pork shoulder roast',
#  'satsuma juice',
#  'codfish',
#  'dripping',
#  'konbu',
#  'fillet steaks',
#  'ground ginger',
#  'elbow pasta',
#  'glutinous rice flour',
#  'asafoetida',
#  'macadamia nuts',
#  'sweet rice wine',
#  'vanilla instant pudding',
#  'whole grain pasta',
#  'red currants',
#  'risotto',
#  'yellow bean sauce',
#  'chilled seltzer',
#  'glutinous rice',
#  'vegetable bouillon cube',
#  'pastry shell',
#  'chaat masala',
#  'fresh blueberries',
#  'pimento stuffed green olives',
#  'shredded coconut',
#  'dried arbol chile',
#  'pepperidge farm puff pastry',
#  'mini m ms',
#  'soy nuts',
#  'fryer chickens',
#  'fresh parsley',
#  'cooked vermicelli',
#  'picholine',
#  'chile paste',
#  'sanding sugar',
#  'sansho',
#  'white button mushrooms',
#  'whole wheat submarine loaves',
#  'low fat coconut milk',
#  'achiote paste',
#  'bibb lettuce',
#  'runny honey',
#  'mung beans',
#  'seedless green grape',
#  'sliced apples',
#  'garden peas',
#  'puff pastry cups',
#  'beef shank',
#  'plum sauce',
#  'quick yeast',
#  'kecap manis',
#  'white wine',
#  'radicchio',
#  'chilli paste',
#  'heeng',
#  'lemon juice',
#  'chopped fresh herbs',
#  'gluten',
#  'tzatziki',
#  'ground tumeric',
#  'light corn syrup',
#  'textured soy protein',
#  'rice syrup',
#  'mandarin orange segments',
#  'navel oranges',
#  'organic cane sugar',
#  'chinese turnip',
#  'finely chopped fresh parsley',
#  'shao hsing wine',
#  'candied fruit',
#  'ganache',
#  'chunky pasta sauce',
#  'cream of chicken soup',
#  'grissini',
#  'whole wheat linguine',
#  'spice',
#  'pastis',
#  'fresh chives',
#  'oat milk',
#  'knorr chipotl minicub',
#  'smoked trout',
#  'vanilla powder',
#  'ground chuck',
#  'italian rolls',
#  'frozen chopped spinach',
#  'lower sodium beef broth',
#  'kipper',
#  'shucked oysters',
#  'mascarpone',
#  'hot italian turkey sausage',
#  'hand',
#  'blood orange',
#  'ch vre',
#  'pie',
#  'pumpkin pie spice',
#  'bottled chili sauce',
#  'chili pepper flakes',
#  'ground cinnamon',
#  'medium shrimp uncook',
#  'sodium free chicken stock',
#  'black grapes',
#  'banana',
#  'grape',
#  'cabbage head',
#  'reduced sodium chicken broth',
#  'Hidden Valley  Original Ranch  Dressing',
#  'french fri frozen',
#  'potato flour',
#  'bay leaf',
#  'vegan yogurt',
#  'sherry',
#  'manouri',
#  'nonfat chicken broth',
#  'black cherries',
#  'shoulder lamb chops',
#  'head on shrimp',
#  'sour salt',
#  'Uncle Ben s Ready Rice Whole Grain Brown Rice',
#  'daikon sprouts',
#  'chayotes',
#  'red chile sauce',
#  'fresh mint',
#  'tarragon vinegar',
#  'meat bones',
#  'Godiva Chocolate Liqueur',
#  'pure acai puree',
#  'celery heart',
#  'borage',
#  '    less sodium taco seasoning mix',
#  'rye bread',
#  'collard green leaves',
#  'chile sauce',
#  'natural low fat yogurt',
#  'strawberry extract',
#  'bean threads',
#  'cooked rice',
#  'new york strip steaks',
#  'tamale',
#  'chocolate syrup',
#  '    oz   refried beans',
#  'stem ginger in syrup',
#  'gluten free tamari',
#  'great northern beans',
#  'fat trimmed beef flank steak',
#  'boned lamb shoulder',
#  'lamb',
#  'veal knuckle',
#  'turkey meatballs',
#  'dulong',
#  'nappa cabbage',
#  'water',
#  'alfredo sauce mix',
#  'lambrusco',
#  'frozen bread dough',
#  'flavored rice mix',
#  'dried hibiscus blossoms',
#  'carambola',
#  'sandwich buns',
#  'pumpkin seed mole',
#  'chorizo spanish',
#  'peaches in syrup',
#  'seasoning',
#  'tangerine',
#  'Martha White Cornbread Mix',
#  'beef tendons',
#  'frozen sweet corn',
#  'drumstick',
#  'rubbed sage',
#  'blanched almonds',
#  'white bread flour',
#  'lox',
#  'eye of round roast',
#  'jelly',
#  'juniper berries',
#  'gluten free corn tortillas',
#  'wheel',
#  'fresno pepper',
#  'St Germain Liqueur',
#  'bulgur wheat',
#  'potato',
#  'cheddar cheese',
#  'beef liver',
#  'balm',
#  'fresh white truffles',
#  'almond extract',
#  'mandarin orange juice',
#  'sweet chili sauce',
#  'ground sichuan pepper',
#  'licorice root',
#  'flounder fillets',
#  'tom yum paste',
#  'onion flakes',
#  'sausage meat',
#  'olive oil flavored cooking spray',
#  'asian pear',
#  'almond butter',
#  'fish bones',
#  'hot pork sausage',
#  'safflower',
#  'ground thyme',
#  'green bellpepper',
#  'cocktail sauce',
#  'glucose syrup',
#  'chicken carcass',
#  'bread  cut into italian loaf',
#  'cooking salt',
#  'evaporated milk',
#  'smoked hog jowl',
#  'finely ground coffee',
#  'skinless cod fillets',
#  'sesame chili oil',
#  'groundnut',
#  'cherry syrup',
#  'salmon fillets',
#  'cocoa powder',
#  'Louisiana Hot Sauce',
#  'bbq seasoning',
#  'low fat vegetable primavera spaghetti sauce',
#  'andouille sausage',
#  'veal demi glace',
#  'english breakfast tea',
#  'Italian turkey sausage links',
#  'pummelo',
#  'melted fat',
#  'brioche buns',
#  'red mullet',
#  'Madeira',
#  'peeled diced tomatoes',
#  'red currant jelly',
#  'jamaican curry powder',
#  'japanese pumpkin',
#  'mizuna',
#  'vegan chicken flavored bouillon',
#  'double smoked bacon',
#  'Irish Red ale',
#  'dried cherry',
#  'mahi mahi fillets',
#  'kiwifruit',
#  'habanero',
#  'conger eel',
#  'canola mayonnaise',
#  'pie filling',
#  'pineapple preserves',
#  'rib',
#  'crema mexicana',
#  'Earth Balance Buttery Spread',
#  'kefir',
#  'bourbon liqueur',
#  'Old El Paso  mild red enchilada sauce',
#  'black cumin seeds',
#  'emerils original essence',
#  'canadian bacon',
#  'cooking spray',
#  'port wine',
#  'white truffle oil',
#  'Lipton  Iced Tea Brew Family Size Tea Bags',
#  'spinach tortilla',
#  'Gold Medal All Purpose Flour',
#  'chopped pecans',
#  'tart apples',
#  'shaved chocolate',
#  'fat',
#  'i can t believ it  not butter  made with olive oil spread',
#  'shishito chile',
#  'smoked ham',
#  'Corn Flakes Cereal',
#  'whipped butter',
#  'chile pepper',
#  'condensed cream of mushroom soup',
#  'ground chicken',
#  'winesap',
#  'green split peas',
#  'prime rib',
#  'hearts of palm',
#  'cheddar cheese soup',
#  'yellow lentils',
#  'frisee',
#  'celery powder',
#  'Himalayan salt',
#  'dried chile peppers',
#  'standing rib roast',
#  'caramel ice cream topping',
#  'unbaked pie shells',
#  'boneless steak',
#  'center cut loin pork chop',
#  'unsalted cashews',
#  'bow',
#  'french onion soup',
#  'picholine olives',
#  'flounder',
#  'frozen peas and carrots',
#  'chicken heart',
#  'alcohol',
#  'sweet yellow corn',
#  'cornflake cereal',
#  'Foster Farms boneless skinless chicken breasts',
#  'nonfat yogurt plain',
#  'wood ear mushrooms',
#  'hot cherry pepper',
#  'whole allspice',
#  'chicken wing drummettes',
#  'tapioca',
#  'japanese cucumber',
#  'ghee',
#  'fresh cranberries',
#  'fruit juice',
#  'fresh ginger',
#  'Kung Pao sauce',
#  'fresh bean',
#  'mixed fruit',
#  'espresso powder',
#  'wish bone ranch dress',
#  'black sesame seeds',
#  'chenpi',
#  'condensed chicken broth',
#  'butter flavor vegetable shortening',
#  'unsalted vegetable stock',
#  'annatto oil',
#  'medium dry sherry',
#  'fish paste',
#  'mild cheddar cheese',
#  'sweetened coconut flakes',
#  'tilapia',
#  'belacan',
#  'milkfish',
#  'golden raisins',
#  'barolo',
#  'lavender buds',
#  'masago',
#  'Old El Paso  refried beans',
#  'White Lily Flour',
#  'ground peanut',
#  'Hellmann s Dijonnaise Creamy Dijon Mustard',
#  'squid tube',
#  'beef deli roast slice thinli',
#  'fresh lima beans',
#  'fresh herbs',
#  'pork rind',
#  'whole wheat pita',
#  'Toulouse sausage',
#  'wasabi paste',
#  'ox tongue',
#  'Pale Ale',
#  'atta',
#  'smoked pork neck bones',
#  'Japanese soy sauce',
#  'ground caraway',
#  'lotus seed paste',
#  'coarse ground mustard',
#  'boneless skinless chicken breast halves',
#  'hot green chile',
#  'green bell pepper  slice',
#  'silver tequila',
#  'gingerroot',
#  'dried pasta',
#  'fresh cilantro',
#  'frozen cod fillets',
#  'non fat chicken stock',
#  'shredded zucchini',
#  'creole spice mix',
#  'peeled tomatoes',
#  'carne asada',
#  'caciocavallo',
#  'smoked sausage',
#  'oleo',
#  'dairy free coconut ice cream',
#  'double concentrate tomato paste',
#  'wondra',
#  'coriander',
#  'champagne grapes',
#  'hoagie buns',
#  'ginger pur e',
#  'fajita size flour tortillas',
#  'fresh green bean',
#  'cassava root flour',
#  'instant couscous',
#  'tandoori paste',
#  'daikon',
#  'coffee liqueur',
#  'promise buttery spread',
#  'uncooked ziti',
#  'grated horseradish',
#  'cheese dip',
#  'energy drink',
#  'cactus paddles',
#  'Mexican lager beer',
#  'chinese hot mustard',
#  'lamb rib chops',
#  'shredded Monterey Jack cheese',
#  'Quorn Chik  n Tenders',
#  'biga',
#  'Bob Evans Italian Sausage',
#  'asadero',
#  'Haas avocados',
#  'gran marnier',
#  'Nakano Seasoned Rice Vinegar',
#  'dried fish flakes',
#  'spanish rice',
#  'instant espresso powder',
#  'sucralose sweetener',
#  'free range chickens',
#  'Zatarains Creole Seasoning',
#  'fresh bay leaves',
#  'vanilla flavoring',
#  'other vegetables',
#  'gray salt',
#  'mission figs',
#  'vindaloo paste',
#  'mole poblano',
#  'fat free mayonnaise',
#  'fudge brownie mix',
#  'low fat cheddar',
#  'color food orang',
#  'dill',
#  'compressed yeast',
#  'crescent dinner rolls',
#  'rosemary sprigs',
#  'pepitas',
#  'garlic',
#  'duck bones',
#  'capocollo',
#  'roasted peanuts',
#  'nut',
#  'george dickel',
#  'Vietnamese coriander',
#  'vegetable stock',
#  'toasted sesame oil',
#  'hamburger buns',
#  'round',
#  'sweet pickle juice',
#  'fat free less sodium chicken broth',
#  'low sodium black beans',
#  'sweetbread',
#  'cremini mushrooms',
#  'vanilla extract',
#  'glucose',
#  'peach juice',
#  'foccacia',
#  'basil leaves',
#  'lamb cutlet',
#  'Herdez Salsa Verde',
#  'soy yogurt',
#  'shredded nori',
#  'oyster',
#  'chees fresh mozzarella',
#  'accompaniment',
#  'kabocha squash',
#  'pork spareribs',
#  'pear',
#  'serrano ham',
#  'nori furikake',
#  'kale',
#  'chicken cutlets',
#  'whole wheat orzo',
#  'umeboshi vinegar',
#  'fat skimmed reduced sodium chicken broth',
#  'medium egg noodles',
#  'chocolate candy bars',
#  'soft corn tortillas',
#  'soybean paste',
#  'cajun seasoning',
#  'rice sticks',
#  'chinese barbecue sauce',
#  'white cannellini beans',
#  'tater tots',
#  'pimenton',
#  'miniature chocolate chips',
#  'cayenne pepper sauce',
#  'Franks Hot Sauce',
#  'tart filling',
#  'foot',
#  'filipino eggplant',
#  'crumbled cornbread',
#  'kefalotyri',
#  'Pernod Liqueur',
#  'chive blossoms',
#  'broiler fryers',
#  'light tuna packed in olive oil',
#  'whole wheat rigatoni',
#  'Goya Ground Cumin',
#  'trout caviar',
#  'merlot',
#  'red apples',
#  'cr me de cassis',
#  'soda water',
#  'Robert Mondavi Fume Blanc',
#  'creamer potatoes',
#  'aged cheddar cheese',
#  'sub rolls',
#  'Asian sweet chili sauce',
#  'pomelo',
#  'caramel',
#  'baking chocolate',
#  'roasted garlic oil',
#  'Jose Cuervo',
#  'tart crust',
#  'butter flavor shortening',
#  'melissa',
#  'friselle',
#  'pita',
#  'langoustine',
#  'rice',
#  'portabello mushroom',
#  'pizza seasoning',
#  'black chicken',
#  'prepar salsa',
#  'Kraft Grated Parmesan Cheese',
#  'casing',
#  'maple syrup',
#  'fresh mozzarella balls',
#  'sichuan peppercorn oil',
#  'fresh coriander',
#  'do chua',
#  'zinfandel',
#  'graham flour',
#  'raclette',
#  'clams  well scrub',
#  'ground espresso',
#  'coars ground black pepper',
#  'barilla',
#  'pickled vegetables',
#  'mixed bell peppers',
#  'chocolate sandwich cookies',
#  'lillet',
#  'frozen whip topping  thaw',
#  'light lager',
#  'brown gravy mix',
#  'spring mix',
#  'dr  pepper',
#  'fine salt',
#  'yukon gold potatoes',
#  'beef rump steaks',
#  'frozen mashed potatoes',
#  'tree ears',
#  'lemon wedge',
#  'green lentil',
#  'caramel flavored syrup',
#  'arborio rice',
#  'lamb cubes',
#  'breadcrumb mix',
#  'baby spinach leaves',
#  'marinara sauce',
#  'black rice vinegar',
#  'butter beans',
#  'tuong',
#  'wish bone guacamol ranch dress',
#  'Kraft Shredded Pepper Jack Cheese',
#  'paccheri',
#  'Pillsbury Thin Pizza Crust',
#  'reduced sodium teriyaki sauce',
#  'cider vinegar',
#  'rustic rub',
#  'lingcod',
#  'creme de cacao',
#  'lamb chops',
#  'crushed cornflakes',
#  'dried bonito',
#  'jackfruit',
#  'Ranch Style Beans',
#  'distilled vinegar',
#  'celery salt',
#  'tikka masala curry paste',
#  'crab',
#  'dried lavender blossoms',
#  'ground bison',
#  'caraway seeds',
#  'cooked meat',
#  'self raising flour',
#  'bean thread vermicelli',
#  'Smithfield Ham',
#  'Wolf Brand Chili',
#  'puffed rice',
#  'natto',
#  'brown beech mushrooms',
#  'lasagna sheets',
#  'peasant bread',
#  'sliced olives',
#  ...]

# %%
testframe['lemmatized_ingredients'] = [(' ').join(lemmatizer.lemmatize(re.sub("[^a-zA-Z $]", " ", str(ingredient))) for ingredient in ingredients_list) for ingredients_list in testframe['ingredients']]

trainframe['lemmatized_ingredients'] = [(' ').join(lemmatizer.lemmatize(re.sub("[^a-zA-Z $]", " ", str(ingredient))) for ingredient in ingredients_list) for ingredients_list in trainframe['ingredients']]

# %%
# drop redundant data

trainframe.drop(["id", "ingredients"], axis=1, inplace=True)
testframe.drop(["ingredients"], axis=1, inplace=True)

# %%
vectorizer = TfidfVectorizer()

trainingredients = np.asarray(vectorizer.fit_transform(trainframe['lemmatized_ingredients']).todense())
testingredients = np.asarray(vectorizer.transform(testframe['lemmatized_ingredients']).todense())

# %%
# just to visualize data, redundant code
df = pd.read_json("train.json")
df.drop(["ingredients", "id"], axis=1, inplace=True)
df1 = pd.DataFrame(trainingredients, columns=vectorizer.get_feature_names_out())
res = pd.concat([df, df1], axis=1)
res
trainframe['cuisine']
# Out:
# 0              greek
# 1        southern_us
# 2           filipino
# 3             indian
# 4             indian
#             ...
# 39769          irish
# 39770        italian
# 39771          irish
# 39772        chinese
# 39773        mexican
# Name: cuisine, Length: 39774, dtype: object

# %%
cuisine_encoder = LabelEncoder()
encoded_cuisine = cuisine_encoder.fit_transform(trainframe['cuisine'].values.reshape(-1,1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # **Training model**

# %%
classifier = LogisticRegression(solver='liblinear')

X_train, X_test, y_train, y_test = train_test_split(trainingredients, encoded_cuisine, test_size=0.20)
classifier.fit(X_train, y_train)

y_predict = classifier.predict(X_test)
accuracy_score(y_test, y_predict)

# cross_val_score(classifier, trainingredients, encoded_cuisine)
# Out:
# 0.774732872407291

# %%
parameters = {
    # 'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}

clf = GridSearchCV(classifier, parameters)

clf.fit(trainingredients, encoded_cuisine)
# Out:
# GridSearchCV(estimator=LogisticRegression(solver='liblinear'), param_grid={})

# %% [markdown]
# # **Decoding and exporting data**

# %%
y_test_predict = classifier.predict(testingredients)
result_decoded = cuisine_encoder.inverse_transform(y_test_predict)

# %%
result_decoded
# Out:
# array(['british', 'southern_us', 'italian', ..., 'italian', 'southern_us',
#        'mexican'], dtype=object)

# %%
submission = pd.DataFrame({'id': testframe['id'], 'cuisine': result_decoded})
submission.to_csv('submission.csv', index=False)
